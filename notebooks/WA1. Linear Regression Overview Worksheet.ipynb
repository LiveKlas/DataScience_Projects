# %%
# !pip install linreg
# Out:
# Collecting linreg
#   Downloading linreg-0.1.2-py3-none-any.whl (3.8 kB)
# Collecting scikit-learn==1.1.0 (from linreg)
#   Downloading scikit_learn-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 42.6 MB/s eta 0:00:00
# Collecting matplotlib==3.5.2 (from linreg)
#   Downloading matplotlib-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 52.1 MB/s eta 0:00:00
# Collecting numpy==1.22.3 (from linreg)
#   Downloading numpy-1.22.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 70.9 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->linreg) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.0->linreg) (1.11.4)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.0->linreg) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.1.0->linreg) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.5.2->linreg) (1.16.0)
# Installing collected packages: numpy, matplotlib, scikit-learn, linreg
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.11.1 requires matplotlib>=3.7.1, but you have matplotlib 3.5.2 which is incompatible.
# bigframes 1.11.1 requires scikit-learn>=1.2.2, but you have scikit-learn 1.1.0 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.22.3 which is incompatible.
# cudf-cu12 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.3 which is incompatible.
# numexpr 2.10.1 requires numpy>=1.23.0, but you have numpy 1.22.3 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.22.3 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.2 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.22.3 which is incompatible.
# pywavelets 1.6.0 requires numpy<3,>=1.22.4, but you have numpy 1.22.3 which is incompatible.
# rmm-cu12 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.3 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.22.3 which is incompatible.
# Successfully installed linreg-0.1.2 matplotlib-3.5.2 numpy-1.22.3 scikit-learn-1.1.0

# %%
# %pylab inline
import linreg
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module was compiled against NumPy C-API version 0x10 (NumPy 1.23) but the running NumPy has C-API version 0xf. Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem.

# %%
linreg.lab_experiments()

# %%
linreg.linreg_example()
# Out:
# Slope = 1.965552
# Intercept = 0.789555

# %%
linreg.make_data_points()
# Out:
# (array([ 0.        ,  0.26315789,  0.52631579,  0.78947368,  1.05263158,
#         1.31578947,  1.57894737,  1.84210526,  2.10526316,  2.36842105,
#         2.63157895,  2.89473684,  3.15789474,  3.42105263,  3.68421053,
#         3.94736842,  4.21052632,  4.47368421,  4.73684211,  5.        ]),
#  array([  0.39764617,   1.26578746,   1.29291222,   1.80108222,
#          3.58815344,   3.82828186,   3.70434868,   4.3250836 ,
#          5.0950376 ,   5.86005947,   6.26675257,   5.64136313,
#          6.95328529,   7.4565617 ,   8.54487947,   8.83795151,
#          7.92023398,   9.26144715,  10.80819687,  10.28071513]))

# %%
linreg.lab_experiments()

# %%
linreg.lab_experiments(1000,2003)

# %%
x,y = linreg.make_data_points()
linreg.make_single_plot(x,y,'Force','Acceleration','Lab Experiment')

# %%
linreg.lab_experiment()

# %% [markdown]
# ---
# data exploration
# ---

# %%
import pandas as pd
#loansDataRaw = pd.read_csv('https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv')
loansmin = pd.read_csv('https://raw.githubusercontent.com/LiveKlas/DataScience_Projects/main/Data/loanf.csv')

# %%
loansmin.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %% [markdown]
# ---
# data analysis
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = pd.plotting.scatter_matrix(loansmin,alpha=0.6,figsize=(9,9), diagonal='kde')

# %%
a = pd.plotting.scatter_matrix(loansmin,alpha=0.05,figsize=(9,9), diagonal='kde')
